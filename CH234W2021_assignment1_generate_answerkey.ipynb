% %% [markdown]
% # assignment one. generate answers from concentration

% %%
M=0.02606;

% %%
pH=7; value1=pH;
pH=-log10(M);
value2=pH;
pH=-log10(1e-14/M); value3=pH;
pH=-log10(M*2); value4=pH;

a=1; b=M*2*1e-6; c=-1*1e-14; t=roots([a b c]);
t(imag(t)==0); %sets any imaginary roots to zero
% display the positive real root
t=t(t>0);

pH=-log10(t); value5=pH;

pH=7.000; value6=pH;
 
format short
Q1=[value1 value2 value3 value4 value5 value6]
 
MM=M;

value1=1e-7;
Cl=MM; value2=Cl;
Na=MM; value3=Na;
SO4=MM; value4=SO4;

a=1; b=MM*2*1e-6; c=-1*1e-14; t=roots([a b c]);
t(imag(t)==0); %sets any imaginary roots to zero
% display the positive real root
t=t(t>0);

H=t; value5=H;

Na1=0.01*0.01; Na2=0.01*MM*2; Na=(Na1+Na2)/0.02;

value6=Na;

format short e
Q2=[value1 value2 value3 value4 value5 value6]
% Out:
% Q1 =
%
%     7.0000    1.5840   12.4160    1.2830    7.1119    7.0000
%
% Q2 =
%
%    1.0000e-07   2.6060e-02   2.6060e-02   2.6060e-02   7.7280e-08   3.1060e-02
