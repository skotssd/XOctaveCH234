% %%
%housekeeping
%graphics_toolkit ("plotly")
%graphics_toolkit ("notebook")
clear
% end of housekeeping

% %% [markdown]
% ## title slide

% %% [markdown]
%  put in some text
%
%  and a an itemized list
%   list 1
%   list 2
%   list 3

% %% [markdown]
% put in some code

% %%
x=[3 4 5]; y=[1 1 7]; plot(x,y,'k-','linewidth',2)
hold on
plot(x,y,'ko','markerfacecolor','b')
set(gca,'linewidth',2,'fontsize',12)
